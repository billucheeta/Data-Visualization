# %% [markdown]
# # Import Package

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ## Basic Plot

# %%
x = [10,20,30,40,50]
y = [45,75,30,80,40]
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Bar Graph

# %%
x = ['Ajay', 'Tom', 'Vicky', 'Anouska','Mikhail']
y = [4500, 7500, 3000, 8000, 40000]
plt.title('Bar Graph')
plt.xlabel('Employees')
plt.ylabel('Salary')
plt.bar(x,y,color='red',alpha=1)
plt.show()

# %% [markdown]
# ## Show values and label at the top of the graph

# %%
barplot = plt.bar(x, y)
for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')
    
plt.title(" Bar graph example")
plt.xlabel('Employees')
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Increase Size of Graph

# %%
plt.figure(figsize=(7,7))
barplot = plt.bar(x, y)
for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom') 
plt.title(" Bar graph example")
plt.xlabel('Employees')
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Hide axis

# %%
plt.figure(figsize=(7,7))
barplot = plt.bar(x, y)
for bar in barplot:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')
    plt.yticks([])
plt.title(" Bar graph example")
plt.xlabel('Employees')
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# ## Horizontal Bar Graph

# %%
plt.barh(x,y)
plt.title("Horizontal Bar graph example")
plt.xlabel("Employees")
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Order Bars

# %%
y,x = zip(*sorted(zip(y,x)))
plt.barh(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
y,x = zip(*sorted(zip(y,x)))
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x,y)
ax=plt.subplot()
ax.invert_yaxis()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ## Themes/Styles of Graph

# %%
plt.barh(x,y)
plt.title("Horizontal Bar graph example")
plt.xlabel("Employees")
plt.ylabel('Salary')
plt.style.use('dark_background')

# %%
plt.barh(x,y)
plt.title("Horizontal Bar graph example")
plt.xlabel("Employees")
plt.ylabel('Salary')
plt.style.use('seaborn-dark-palette')

# %% [markdown]
# ## Line Graph

# %%
import pandas as pd

df = pd.DataFrame({"Year" : [2015,2016,2017,2018,2019], 
                  "Salary_Hike" : [2000, 3000, 4000, 3500, 6000]})

# %%
# plot line chart
plt.plot(df["Year"], df["Salary_Hike"])
plt.title("Simple Line Plot")
plt.xlabel('Year')
plt.ylabel('Salary_Hike')
plt.style.use('seaborn-white')

# %% [markdown]
# ## Add Marker in Line Plot

# %%
ax = df.plot(x="Year", y="Salary_Hike", kind="line", title ="Simple Line Plot", legend=True, style = 'b--')
ax.set(ylabel='Salary_Hike', xlabel = 'Year', xticks =df["Year"])
# Out:
# [Text(0, 0.5, 'Salary_Hike'),
#  [<matplotlib.axis.XTick at 0x2ae95158948>,
#   <matplotlib.axis.XTick at 0x2ae95152fc8>,
#   <matplotlib.axis.XTick at 0x2ae95183548>,
#   <matplotlib.axis.XTick at 0x2ae95188708>,
#   <matplotlib.axis.XTick at 0x2ae95188c88>],
#  Text(0.5, 0, 'Year')]

# %% [markdown]
# ## Add Multiple Lines on the Line Graph

# %%
import pandas as pd

product = pd.DataFrame({"Year" : [2014,2015,2016,2017,2018], 
                  "ProdAManufacture" : [2000, 3000, 4000, 3500, 6000],
                  "ProdBManufacture" : [3000, 4000, 3500, 3500, 5500]})


# Multi line plot
ax = product.plot("Year", "ProdAManufacture", kind="line", label = 'Product A manufacture')
product.plot("Year", "ProdBManufacture", ax= ax , kind="line", label = 'Product B manufacture', title= 'MultiLine Plot') #ax : axes object

# Set axes
ax.set(ylabel='Sales', xlabel = 'Year', xticks =df["Year"])
# Out:
# [Text(0, 0.5, 'Sales'),
#  [<matplotlib.axis.XTick at 0x2ae95586b48>,
#   <matplotlib.axis.XTick at 0x2ae95586688>,
#   <matplotlib.axis.XTick at 0x2ae955bfb48>,
#   <matplotlib.axis.XTick at 0x2ae955c5c08>,
#   <matplotlib.axis.XTick at 0x2ae955c9188>],
#  Text(0.5, 0, 'Year')]

# %% [markdown]
# ## Scatter Plot

# %%
ax = product.plot("Year", "ProdAManufacture", kind='scatter', color = 'red', title = 'Year by ProductA Manufacture')
ax.set(ylabel='ProdAManufacture', xlabel = 'Year', xticks =df["Year"])
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
Goals = [20, 12, 11, 4, 3]
players = ['Ronaldo', 'Messi', 'Suarez', 'Neymar', 'Salah', ]
comp = pd.DataFrame({"Goals" : Goals, "players" : players})
ax = comp.plot(y="Goals", kind="pie", labels = comp["players"], autopct = '%1.0f%%', legend=True, title='No of Goals scored')

# Hide y-axis label
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]

# %% [markdown]
# ## Customize Pie Chart

# %%
ax = comp.plot(y="Goals", kind="pie", labels = comp["players"], startangle = 90, shadow = True, 
        explode = (0.1, 0.1, 0.1, 0, 0), autopct = '%1.0f%%', legend=True, title='No of Goals scored')
ax.set(ylabel='')
plt.show()

# %% [markdown]
# ## Histrogram

# %%
import numpy as np
np.random.seed(1)
mydf = pd.DataFrame({"Age" : np.random.randint(low=20, high=100, size=50)})

# Histogram
ax = mydf.plot(bins= 5, kind="hist", rwidth = 0.7, title = 'Distribution - Marks', legend=False)
ax.set(xlabel="Bins")
plt.show()

# %% [markdown]
# ## Add Multiple sub-plots

# %%
labels = ['Amsterdam', 'Berlin', 'Brussels', 'Paris']
x1 = [45, 30, 15, 10]
x2 = [25, 20, 25, 50]

finaldf = pd.DataFrame({"2017_Score":x1, "2018_Score" : x2, "cities" : labels})

# %%
finaldf
# Out:
#    2017_Score  2018_Score     cities
# 0          45          25  Amsterdam
# 1          30          20     Berlin
# 2          15          25   Brussels
# 3          10          50      Paris

# %%
fig = plt.figure()

ax1 = fig.add_subplot(121)
ax = finaldf.plot(x="cities",  y="2017_Score", ax=ax1, kind="barh", legend = False, title = "2017 Score")
ax.invert_yaxis()

ax2 = fig.add_subplot(122)
ax = finaldf.plot(x="cities",  y="2018_Score", ax=ax2, kind="barh", legend = False, title = "2018 Score")
ax.invert_yaxis()
ax.set(ylabel='')
# Out:
# [Text(0, 0.5, '')]
